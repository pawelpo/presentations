# %% [markdown]
# # **Ad-hoc analysis over semantic model**

# %%
# %%sql
# SELECT t.Year, t.`Month Number`, t.`Month Name`, SUM(f.Profit) AS Profit
# FROM Time AS t
# LEFT JOIN Financials AS f
# ON t.Date = f.Date
# GROUP BY t.Year, t.`Month Number`, t.`Month Name`
# ORDER BY t.Year, t.`Month Number`
# Out:
# StatementMeta(, 9ec1cb75-345e-4e4a-bd71-7f842f9555b7, 3, Finished, Available)
# <Spark SQL result set with 16 rows and 4 fields>
