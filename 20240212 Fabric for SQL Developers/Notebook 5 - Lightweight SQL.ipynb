# %% [markdown]
# # **Lightweight SQL engine (DuckDB)**

# %%
pip install duckdb==0.9.2
# Out:
# StatementMeta(, abd5323c-85f1-4b22-a92a-89481062c43c, 7, Finished, Available)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 102.4 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import duckdb

df = pd.read_parquet("/lakehouse/default/Files/raw/trips/")

df_result = duckdb.sql("select count(*) from df;").to_df()

display(df_result)
# Out:
# StatementMeta(, abd5323c-85f1-4b22-a92a-89481062c43c, 14, Finished, Available)
# SynapseWidget(Synapse.DataFrame, 1885ef82-6429-4a6a-8e36-acbf26d446d9)
